# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
import numpy as np
import datetime as dt
from datetime import datetime
from datetime import timedelta

# %%
# import datafiles
csv_airports = "../ETL_Project/CSV_files/airports.csv"
airports_df = pd.read_csv(csv_airports)
csv_flights = "../ETL_Project/CSV_files/flights.csv"
flights_df = pd.read_csv(csv_flights)

# %%
flights_df = flights_df.dropna(axis='columns')
flights_df = flights_df.drop(columns=["CANCELLED", "DIVERTED"])
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0  2015      1    1            4      AS             98            ANC
# 1  2015      1    1            4      AA           2336            LAX
# 2  2015      1    1            4      US            840            SFO
# 3  2015      1    1            4      AA            258            LAX
# 4  2015      1    1            4      AS            135            SEA
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DISTANCE  SCHEDULED_ARRIVAL
# 0                 SEA                    5      1448                430
# 1                 PBI                   10      2330                750
# 2                 CLT                   20      2296                806
# 3                 MIA                   20      2342                805
# 4                 ANC                   25      1448                320

# %%
# choose Delta flights from Atlanta
delta_flights = flights_df.loc[(flights_df["AIRLINE"] == "DL")]
delta_flights = delta_flights.loc[(delta_flights["ORIGIN_AIRPORT"] == "ATL")]
delta_flights.head()
# Out:
#       YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 729   2015      1    1            4      DL            886            ATL
# 815   2015      1    1            4      DL           1818            ATL
# 1167  2015      1    1            4      DL           2499            ATL
# 1215  2015      1    1            4      DL           1260            ATL
# 1273  2015      1    1            4      DL           2103            ATL
#
#      DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DISTANCE  SCHEDULED_ARRIVAL
# 729                  LGA                  645       762                853
# 815                  MCO                  655       404                822
# 1167                 SLC                  720      1590                940
# 1215                 BDL                  725       859                940
# 1273                 MIA                  730       594                926

# %%
airports_df = airports_df.drop(columns=["COUNTRY", "LATITUDE", "LONGITUDE"])
airports_df = airports_df.rename(columns={"IATA_CODE" : "DESTINATION_AIRPORT"})
airports_df.head()
# Out:
#   DESTINATION_AIRPORT                              AIRPORT         CITY STATE
# 0                 ABE  Lehigh Valley International Airport    Allentown    PA
# 1                 ABI             Abilene Regional Airport      Abilene    TX
# 2                 ABQ    Albuquerque International Sunport  Albuquerque    NM
# 3                 ABR            Aberdeen Regional Airport     Aberdeen    SD
# 4                 ABY   Southwest Georgia Regional Airport       Albany    GA

# %%
combined_data_df = pd.merge(airports_df, delta_flights,
                                 how='outer', on='DESTINATION_AIRPORT')
combined_data_df = combined_data_df.dropna(axis='rows')
combined_data_df
# Out:
#       DESTINATION_AIRPORT                              AIRPORT  \
# 0                     ABE  Lehigh Valley International Airport
# 1                     ABE  Lehigh Valley International Airport
# 2                     ABE  Lehigh Valley International Airport
# 3                     ABE  Lehigh Valley International Airport
# 4                     ABE  Lehigh Valley International Airport
# ...                   ...                                  ...
# 42381                 XNA  Northwest Arkansas Regional Airport
# 42382                 XNA  Northwest Arkansas Regional Airport
# 42383                 XNA  Northwest Arkansas Regional Airport
# 42384                 XNA  Northwest Arkansas Regional Airport
# 42385                 XNA  Northwest Arkansas Regional Airport
#
#                                  CITY STATE    YEAR  MONTH  DAY  DAY_OF_WEEK  \
# 0                           Allentown    PA  2015.0    1.0  4.0          7.0
# 1                           Allentown    PA  2015.0    1.0  5.0          1.0
# 2                           Allentown    PA  2015.0    1.0  6.0          2.0
# 3                           Allentown    PA  2015.0    1.0  7.0          3.0
# 4                           Allentown    PA  2015.0    1.0  8.0          4.0
# ...                               ...   ...     ...    ...  ...          ...
# 42381  Fayetteville/Springdale/Rogers    AR  2015.0    3.0  5.0          4.0
# 42382  Fayetteville/Springdale/Rogers    AR  2015.0    3.0  6.0          5.0
# 42383  Fayetteville/Springdale/Rogers    AR  2015.0    3.0  7.0          6.0
# 42384  Fayetteville/Springdale/Rogers    AR  2015.0    3.0  8.0          7.0
# 42385  Fayetteville/Springdale/Rogers    AR  2015.0    3.0  9.0          1.0
#
#       AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  SCHEDULED_DEPARTURE  DISTANCE  \
# 0          DL         2036.0            ATL               2101.0     692.0
# 1          DL         1411.0            ATL               2034.0     692.0
# 2          DL         1411.0            ATL               2034.0     692.0
# 3          DL         1411.0            ATL               2034.0     692.0
# 4          DL         1411.0            ATL               2034.0     692.0
# ...       ...            ...            ...                  ...       ...
# 42381      DL         2119.0            ATL               2115.0     589.0
# 42382      DL         2119.0            ATL               2115.0     589.0
# 42383      DL         2119.0            ATL               2115.0     589.0
# 42384      DL         2119.0            ATL               2115.0     589.0
# 42385      DL         2119.0            ATL               2115.0     589.0
#
#        SCHEDULED_ARRIVAL
# 0                 2251.0
# 1                 2225.0
# 2                 2225.0
# 3                 2225.0
# 4                 2225.0
# ...                  ...
# 42381             2214.0
# 42382             2214.0
# 42383             2212.0
# 42384             2214.0
# 42385             2214.0
#
# [42197 rows x 14 columns]

# %%
dayOfWeek={1:'Monday', 2:'Tuesday', 3:'Wednesday', 4:'Thursday', 5:'Friday', 6:'Saturday', 7:'Sunday'}
combined_data_df['WEEKDAY'] = combined_data_df['DAY_OF_WEEK'].map(dayOfWeek).rename()
combined_data_df.head()
# Out:
#   DESTINATION_AIRPORT                              AIRPORT       CITY STATE  \
# 0                 ABE  Lehigh Valley International Airport  Allentown    PA
# 1                 ABE  Lehigh Valley International Airport  Allentown    PA
# 2                 ABE  Lehigh Valley International Airport  Allentown    PA
# 3                 ABE  Lehigh Valley International Airport  Allentown    PA
# 4                 ABE  Lehigh Valley International Airport  Allentown    PA
#
#      YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0  2015.0    1.0  4.0          7.0      DL         2036.0            ATL
# 1  2015.0    1.0  5.0          1.0      DL         1411.0            ATL
# 2  2015.0    1.0  6.0          2.0      DL         1411.0            ATL
# 3  2015.0    1.0  7.0          3.0      DL         1411.0            ATL
# 4  2015.0    1.0  8.0          4.0      DL         1411.0            ATL
#
#    SCHEDULED_DEPARTURE  DISTANCE  SCHEDULED_ARRIVAL    WEEKDAY
# 0               2101.0     692.0             2251.0     Sunday
# 1               2034.0     692.0             2225.0     Monday
# 2               2034.0     692.0             2225.0    Tuesday
# 3               2034.0     692.0             2225.0  Wednesday
# 4               2034.0     692.0             2225.0   Thursday

# %%
combined_data_df = combined_data_df.drop(columns=["DAY_OF_WEEK"])

# %%
combined_data_df = combined_data_df[["MONTH", "DAY" , "YEAR", "WEEKDAY", "DESTINATION_AIRPORT", "AIRPORT", "CITY", "STATE", "ORIGIN_AIRPORT", "AIRLINE", "FLIGHT_NUMBER", "SCHEDULED_DEPARTURE", "SCHEDULED_ARRIVAL", "DISTANCE"]]
combined_data_df["MONTH"] = combined_data_df["MONTH"].astype(float).map("{:.0f}".format)
combined_data_df["DAY"] = combined_data_df["DAY"].astype(float).map("{:.0f}".format)
combined_data_df["YEAR"] = combined_data_df["YEAR"].astype(float).map("{:.0f}".format)
combined_data_df["FLIGHT_NUMBER"] = combined_data_df["FLIGHT_NUMBER"].astype(float).map("{:.0f}".format)
combined_data_df["SCHEDULED_DEPARTURE"] = combined_data_df["SCHEDULED_DEPARTURE"].astype(float).map("{:.0f}".format)
combined_data_df["SCHEDULED_ARRIVAL"]= combined_data_df["SCHEDULED_ARRIVAL"].astype(float).map("{:.0f}".format)
combined_data_df.head()
# Out:
#   MONTH DAY  YEAR    WEEKDAY DESTINATION_AIRPORT  \
# 0     1   4  2015     Sunday                 ABE
# 1     1   5  2015     Monday                 ABE
# 2     1   6  2015    Tuesday                 ABE
# 3     1   7  2015  Wednesday                 ABE
# 4     1   8  2015   Thursday                 ABE
#
#                                AIRPORT       CITY STATE ORIGIN_AIRPORT  \
# 0  Lehigh Valley International Airport  Allentown    PA            ATL
# 1  Lehigh Valley International Airport  Allentown    PA            ATL
# 2  Lehigh Valley International Airport  Allentown    PA            ATL
# 3  Lehigh Valley International Airport  Allentown    PA            ATL
# 4  Lehigh Valley International Airport  Allentown    PA            ATL
#
#   AIRLINE FLIGHT_NUMBER SCHEDULED_DEPARTURE SCHEDULED_ARRIVAL  DISTANCE
# 0      DL          2036                2101              2251     692.0
# 1      DL          1411                2034              2225     692.0
# 2      DL          1411                2034              2225     692.0
# 3      DL          1411                2034              2225     692.0
# 4      DL          1411                2034              2225     692.0

# %%
combined_data_df.head()
# Out:
#   MONTH DAY  YEAR    WEEKDAY DESTINATION_AIRPORT  \
# 0     1   4  2015     Sunday                 ABE
# 1     1   5  2015     Monday                 ABE
# 2     1   6  2015    Tuesday                 ABE
# 3     1   7  2015  Wednesday                 ABE
# 4     1   8  2015   Thursday                 ABE
#
#                                AIRPORT       CITY STATE ORIGIN_AIRPORT  \
# 0  Lehigh Valley International Airport  Allentown    PA            ATL
# 1  Lehigh Valley International Airport  Allentown    PA            ATL
# 2  Lehigh Valley International Airport  Allentown    PA            ATL
# 3  Lehigh Valley International Airport  Allentown    PA            ATL
# 4  Lehigh Valley International Airport  Allentown    PA            ATL
#
#   AIRLINE FLIGHT_NUMBER SCHEDULED_DEPARTURE SCHEDULED_ARRIVAL  DISTANCE
# 0      DL          2036                2101              2251     692.0
# 1      DL          1411                2034              2225     692.0
# 2      DL          1411                2034              2225     692.0
# 3      DL          1411                2034              2225     692.0
# 4      DL          1411                2034              2225     692.0

# %%
rds_connection_string = "postgres:Oscarjoy0305!@localhost:5432/ETL_PROJECT"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['combined_data']

# %%
combined_data_df.to_sql(name='combined_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "MONTH" of relation "combined_data" does not exist
# LINE 1: INSERT INTO combined_data ("MONTH", "DAY", "YEAR", "WEEKDAY"...
#                                    ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-335-e819169f628b> in <module>
# ----> 1 combined_data_df.to_sql(name='combined_data', con=engine, if_exists='append', index=False)
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\OneDrive\Documents\PREWORK_GRW\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "MONTH" of relation "combined_data" does not exist
# LINE 1: INSERT INTO combined_data ("MONTH", "DAY", "YEAR", "WEEKDAY"...
#                                    ^
#
# [SQL: INSERT INTO combined_data ("MONTH", "DAY", "YEAR", "WEEKDAY", "DESTINATION_AIRPORT", "AIRPORT", "CITY", "STATE", "ORIGIN_AIRPORT", "AIRLINE", "FLIGHT_NUMBER", "SCHEDULED_DEPARTURE", "SCHEDULED_ARRIVAL", "DISTANCE") VALUES (%(MONTH)s, %(DAY)s, %(YEAR)s, %(WEEKDAY)s, %(DESTINATION_AIRPORT)s, %(AIRPORT)s, %(CITY)s, %(STATE)s, %(ORIGIN_AIRPORT)s, %(AIRLINE)s, %(FLIGHT_NUMBER)s, %(SCHEDULED_DEPARTURE)s, %(SCHEDULED_ARRIVAL)s, %(DISTANCE)s)]
# [parameters: ({'MONTH': '1', 'DAY': '4', 'YEAR': '2015', 'WEEKDAY': 'Sunday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '2036', 'SCHEDULED_DEPARTURE': '2101', 'SCHEDULED_ARRIVAL': '2251', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '5', 'YEAR': '2015', 'WEEKDAY': 'Monday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '6', 'YEAR': '2015', 'WEEKDAY': 'Tuesday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '7', 'YEAR': '2015', 'WEEKDAY': 'Wednesday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '8', 'YEAR': '2015', 'WEEKDAY': 'Thursday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '9', 'YEAR': '2015', 'WEEKDAY': 'Friday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '11', 'YEAR': '2015', 'WEEKDAY': 'Sunday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}, {'MONTH': '1', 'DAY': '12', 'YEAR': '2015', 'WEEKDAY': 'Monday', 'DESTINATION_AIRPORT': 'ABE', 'AIRPORT': 'Lehigh Valley International Airport', 'CITY': 'Allentown', 'STATE': 'PA', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '1411', 'SCHEDULED_DEPARTURE': '2034', 'SCHEDULED_ARRIVAL': '2225', 'DISTANCE': 692.0}  ... displaying 10 of 42197 total bound parameter sets ...  {'MONTH': '3', 'DAY': '8', 'YEAR': '2015', 'WEEKDAY': 'Sunday', 'DESTINATION_AIRPORT': 'XNA', 'AIRPORT': 'Northwest Arkansas Regional Airport', 'CITY': 'Fayetteville/Springdale/Rogers', 'STATE': 'AR', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '2119', 'SCHEDULED_DEPARTURE': '2115', 'SCHEDULED_ARRIVAL': '2214', 'DISTANCE': 589.0}, {'MONTH': '3', 'DAY': '9', 'YEAR': '2015', 'WEEKDAY': 'Monday', 'DESTINATION_AIRPORT': 'XNA', 'AIRPORT': 'Northwest Arkansas Regional Airport', 'CITY': 'Fayetteville/Springdale/Rogers', 'STATE': 'AR', 'ORIGIN_AIRPORT': 'ATL', 'AIRLINE': 'DL', 'FLIGHT_NUMBER': '2119', 'SCHEDULED_DEPARTURE': '2115', 'SCHEDULED_ARRIVAL': '2214', 'DISTANCE': 589.0})]
# (Background on this error at: http://sqlalche.me/e/13/f405)
